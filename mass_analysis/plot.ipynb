# %%
# import ROOT
# ROOT.PyConfig.StartGuiThread = False

# rdf_nom = ROOT.RDataFrame("nominal", "user.cgarvey.32744802._000002.output.root") 

# h_el_pt = rdf_nom.Histo1D("el_pt") #Book the filling of a histogram

# from ROOT import TCanvas, gROOT
# canvas = TCanvas()
# canvas.SetWindowSize(800, 600)

# h_el_pt.Draw()
# canvas.Draw()
# canvas.SaveAs("el_pt.png")
# canvas.SaveAs("el_pt.pdf")

# %%
from ROOT import TCanvas, TPad, TFile, TPaveLabel, TPaveText, TTree
from ROOT import gROOT
# Out:
# Welcome to JupyROOT 6.24/08

# %%
c1 = TCanvas('c1', 'canvas1', 200, 10, 700, 900 )

# %%
# 1. get tfile
filename = "user.cgarvey.32744802._000002.output.root"
file = TFile(filename)
# 2. get ttree
nominal = file.Get("nominal")
# truth = file.Get("truth")

# 3. manipulate branches on trees
# truth.Draw("MC_t_beforeFSR_pt")
nominal.Draw('mu_pt')

nominal.Draw("el_pt",'','same')
# 4. draw
c1.Draw()

# %%
nominal.Print()
# Out:
# ******************************************************************************
# *Tree    :nominal   : tree                                                   *
# *Entries :   258576 : Total =       896387538 bytes  File  Size =  496762133 *
# *        :          : Tree compression factor =   1.80                       *
# ******************************************************************************
# *Br    0 :mc_generator_weights : vector<float>                               *
# *Entries :   258576 : Total  Size=  228318101 bytes  File Size  =  190471603 *
# *Baskets :     2150 : Basket Size=     197120 bytes  Compression=   1.20     *
# *............................................................................*
# *Br    1 :weight_mc : weight_mc/F                                            *
# *Entries :   258576 : Total  Size=    1142634 bytes  File Size  =     275734 *
# *Baskets :     1091 : Basket Size=       1024 bytes  Compression=   4.06     *
# ...

# %%
nominal.Draw('mu_eta')

nominal.Draw("el_eta",'','same')
# 4. draw
c1.Draw()

# %%
nominal.Draw('mu_phi')

nominal.Draw("el_phi",'','same')
# 4. draw
c1.Draw()

# %%
nominal.Draw('mu_e')

nominal.Draw("el_e",'','same')
# 4. draw
c1.Draw()

# %%
file.ls()
# Out:
# TFile**		user.cgarvey.32744802._000002.output.root
#  TFile*		user.cgarvey.32744802._000002.output.root
#   OBJ: TTree	nominal	tree : 0 at: 0x1201aa0
#   KEY: TDirectoryFile	ee_2015;1	ee_2015
#   KEY: TDirectoryFile	ee_2016;1	ee_2016
#   KEY: TDirectoryFile	ee_2017;1	ee_2017
#   KEY: TDirectoryFile	ee_2018;1	ee_2018
#   KEY: TDirectoryFile	emu_2015;1	emu_2015
#   KEY: TDirectoryFile	emu_2016;1	emu_2016
#   KEY: TDirectoryFile	emu_2017;1	emu_2017
#   KEY: TDirectoryFile	emu_2018;1	emu_2018
#   KEY: TDirectoryFile	mumu_2015;1	mumu_2015
#   KEY: TDirectoryFile	mumu_2016;1	mumu_2016
#   KEY: TDirectoryFile	mumu_2017;1	mumu_2017
#   KEY: TDirectoryFile	mumu_2018;1	mumu_2018
#   KEY: TTree	AnalysisTracking;1
#   KEY: TTree	nominal;1	tree
#   KEY: TTree	particleLevel;1	tree
#   KEY: TTree	sumWeights;1
#   KEY: TTree	truth;1	tree

# %%
nominal.Print()
# Out:
# ******************************************************************************
# *Tree    :nominal   : tree                                                   *
# *Entries :   258576 : Total =       896387538 bytes  File  Size =  496762133 *
# *        :          : Tree compression factor =   1.80                       *
# ******************************************************************************
# *Br    0 :mc_generator_weights : vector<float>                               *
# *Entries :   258576 : Total  Size=  228318101 bytes  File Size  =  190471603 *
# *Baskets :     2150 : Basket Size=     197120 bytes  Compression=   1.20     *
# *............................................................................*
# *Br    1 :weight_mc : weight_mc/F                                            *
# *Entries :   258576 : Total  Size=    1142634 bytes  File Size  =     275734 *
# *Baskets :     1091 : Basket Size=       1024 bytes  Compression=   4.06     *
# ...
